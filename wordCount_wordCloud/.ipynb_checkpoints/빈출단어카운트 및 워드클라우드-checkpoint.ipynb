# %%
import re, time, requests, json
import numpy as np
import pandas as pd
from tqdm import tqdm

import nltk 
from konlpy.corpus import kobill
from konlpy.tag import Okt
okt = Okt()

from PIL import Image
from matplotlib import font_manager, rc
import matplotlib.pyplot as plt
import platform
from wordcloud import WordCloud, STOPWORDS


city_list = ['bangkok','cebu','danang','fukuoka','hanoi','hongkong','osaka','sapporo','taipei','tokyo']

for city in city_list:     ######
    print(city)    

    #데이터전처리
    df = pd.read_csv('C:/Users/twentystones/Desktop/사회연결망분석텀프로젝트/travel_csv/'+city+'_blog_crawling.csv', header=None)
    df.rename(columns= {0:'title', 1:'URL', 2:'day', 3:'body'}, inplace=True)
    
    text = ''
    for i in range(1,90):         #한 도시의 90개 글 모두 한 문장안에 통합
        text = text + df['body'][i]

    #명사 분리.
    tokens_ko=okt.nouns(text)   
#'.', '(', '0', ',', "'", '%', '-', 'X', '),', ').',
    #불용어제거
    stop_words = ['방콕','세부','다낭','후쿠오카','하노이','홍콩','오사카','삿포로','타이페이','도쿄','대만','필리핀','베트남','일본','중국','태국','여행','타이베이','있는','이','그','잘','못','ㅋㅋ','ㅎㅎ','홍콩의','홍콩이','지옥','포기','후회','모양','비현실적']
    tokens_ko = [each_word for each_word in tokens_ko if (each_word not in stop_words)&(len(each_word) !=1)]
    tokens_ko

    #빈출단어 카운트
    ko=nltk.Text(tokens_ko, name=city)
    print('총 단어 수 : ' + str(len(ko.tokens))) #총 단어 수
    print('중복없는 단어 수 : ' + str(len(set(ko.tokens)))) #중복없는 단어 수
    print('단어빈도순정렬 : ')
    ko.vocab()  #단어 빈도순 정렬
    

    #워드그래프
    path = "c:/Windows/Fonts/malgun.ttf"
    if platform.system() == 'Darwin':
        rc('font', family='AppleGothic')
    elif platform.system() == 'Windows':
        font_name = font_manager.FontProperties(fname=path).get_name()
        rc('font', family=font_name)
    else:
        print('Unknown system... sorry~~~~') 
    # %matplotlib inline
    plt.figure(figsize=(14,8))
    plt.title(city)
    ko.plot(50)
    plt.show()

    #워드클라우드
    data = ko.vocab().most_common(200) #단어갯수 조절
    airplain_mask=np.array(Image.open("C:/Users/twentystones/Desktop/사회연결망분석텀프로젝트/airplain.jfif"))
    wc=WordCloud(font_path='c:\windows\Fonts\malgun.ttf',background_color='white', relative_scaling=0.2,
                 stopwords=stop_words, mask=airplain_mask).generate_from_frequencies(dict(data))
    plt.figure(figsize=(20,12))
    plt.imshow(wc)
    plt.axis('off')
    plt.title(city)
    plt.show()
# Out:
# bangkok
# 총 단어 수 : 25278
# 중복없는 단어 수 : 4457
# 단어빈도순정렬 :
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-019a5d93550c> in <module>
#      62     #워드클라우드
#      63     data = ko.vocab().most_common(200) #단어갯수 조절
# ---> 64     airplain_mask=np.array(Image.open("C:/Users/twentystones/Desktop/사회연결망분석텀프로젝트/airplain.jfif"))
#      65     wc=WordCloud(font_path='c:\windows\Fonts\malgun.ttf',background_color='white', relative_scaling=0.2,
#      66                  stopwords=stop_words, mask=airplain_mask).generate_from_frequencies(dict(data))
#
# ~\anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode, formats)
#    2910
#    2911     if filename:
# -> 2912         fp = builtins.open(filename, "rb")
#    2913         exclusive_fp = True
#    2914
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/twentystones/Desktop/사회연결망분석텀프로젝트/airplain.jfif'

# %%
#특정 단어 수가 몇번 나오는지 서칭하고싶다면
ko.count('방콕')
# Out:
# 0

# %%
#등장문장 시각화
plt.figure()
ko.dispersion_plot(['친구','예약','더위'])

# %%
#특정 단어가 들어간 문장 찾기
for i in text.split('.'):
    if '후회' in i:
        print(i)
        print()
# Out:
#   열차 앞부분에 가서 조종하는 곳을 보니 정말 세월이 느껴지는 듯 하더라고요!       ​  나무와 가죽으로 만들어진 손잡이, 레트로 분위기 뿜뿜 느껴지는 벨벳 느낌 실내 좌석 ㅎㅎ 구경하는 사람이 거의 없어서 사진도 자유롭게 찍었어요^^ ​지금 생각하니 사진 좀 더 많이 찍을걸 살짝 후회도 되더라고요~          모양이 하나같이 다 다른게 신기하죠! 이 열차는 모양은 평범한듯 했는데 앞머리 위에 커다란 라이트가 달려 있는게 재미있더라고요 ㅎㅎ          귀여운 얼굴을 하고 있는 니치린
#
# ㅎ 왤까  그리고 내가 후쿠오카에가서 푹빠져버린​빈티지매장투어 여기도 갔는데 이 원피스가 ​만원정도 했나 내 친구랑 찰떡이다 싶어서 바로​친구한테 카톡때림 친구도 맘에 들어했고 바로 결제 ㄱㄱ 여기는 텐진역근처에있는 #북오프 매장 ​여기도 구제 천국 제품이 다양하고 진짜 많다 ​북오프는 책이랑 DVD만 취급하는 매장이있고 ​이렇게 의류나 잡화등을 취급하는 매장이있다 ​저 위 사진은 아빠한테 보내준건데 아빠가 눈독들인게 있으나 ​구제 단점인 사이즈가 없었당  이거는 가족들한테 살까말까 물어보고 별로라고 해서​안산건데 그냥 살껄 ㅠ 아직도 후회 여기는 텐진 파르코백화점 지하1층에있는 ​#키와미야함바그 친구들이 아주 찬양을 했지만 ​별로 내취향은 아니였음  밥을 맛나게 먹고 #키르훼봉 에서 케이크도 샀다 ​하얀딸기 가격은 더 비싼데 내 입맛엔 달지도 않고 ​실망함 =_= 근데 일본인분들은 왜 영어를 잘 모르실까​발음이 왜 다른걸까 스트로베리를 몇번 말했는지 ​모르겠다 허허 얘도 스트로베리네 일본에서 한정으로 나온건데 ​맛은 딱히 특별하진 않았음  숙소에서 재정비를 하고 ​#캐널시티 로 이동 겨울이여서 ​조명을 달아놓은건가 여튼 이뻐서 너무 좋았따   왤케 뿌옇게 찍었지  #동구리공화국 도 갔다 ​캐널시티안에 있는건데 매장은 되게 작음 진짜 필요없는데 괜히 갖고싶었다 ㅋㅋㅋ 갑분 엄청 시끄럼게 노래가 울려퍼져서 나가보니까 ​분수쇼가 시작했다 ㅋㅋㅋ 의도하고 간건 아니였지만​분수쇼를 보개됨 근데 소리가 너무 커서 보다가 ​들어갔다 호호 어떤 애니매이션이었는데 ​난 애니매이션을 잘 몰라서 호호  그렇게 캐널시티를 구경하고 (근데 사실 캐널시티도 한번 가봤어서 그런지 볼게 없음)​나카스강 주위를 걸어다녔다 ​포장마차도 줄지어 있지만 혼자와서 그런지 ​갈 엄두가 안났다 이때 넘 외롭
#
#  총총 (이라기보다는 우다다다)    와 미쳐따 미쳐따 미쳐따 하면서 언니랑 나랑 호들갑 떨고엄마는 절레절레 했고,, 야무진 쇼핑과 약간의 후회(더사고싶어서)를 곁들이고 나랑 언니가 몬치치를 보고 너-무도 행복해하니까 사장님도 신이나셔서 막 유후인 유일의 몬치치 단독 정품샵 뭐라뭐라 설명하시면서달력도 선물해주셨다   야무진 유후인 관람을 끝마치고 만나기로 한 미팅포인트에 도착! 약간 여유있게 도착했던 터라 마트 구경도 하고 다시 후쿠오카로 돌아갈 시간~~~! ​​18:30 정도쯤? 하카타역으로 돌아왔다 하루동안 알찬 여행 하게 해주신 가이드님께 감사인사를 전하고 이쯤이면 저녁을 먹을 줄 알았지? 싶지만ㅋㅋㅋㅋㅋㅋㅋ우리는 또 카페로 향했다 우리의 목적지 중 하나였던 REC COFFEE KITTE 6층에 위치해있는 지점으로 ​   다양한 드립백과 원두를 판매하고 있었고, 커피 시음도 가능했던 점이 좋았다    한 잔이 두 잔이 되고 두 잔이 세 잔이 되어버리는 마!법!긴 여행, 비오는 날씨에 모두 노곤했는지 생각해보니 우리 셋 모두 우유가 들어간 음료를 주문했네?  바리스타 분들도 나이스했다  립톤 프로모션 중​​​  ​ ​오랜만에 나리타 공항처음 일본 도착했을 때 생각나네 불량유심 받아서저녁 될 때 까지 엄마랑 연락 못하고 발 동동 구르던거 ​ ​알죠? 여행은 비행기 안에서 바이바이 하는 아저씨 보면서시작하는 그 두근거림이제 일본 꽤 살았다고 큰 감흥은 없다만요
#
# 이번에는 아래로 내려왔네요​​​  ​후쿠오카여행의 필수코스로 손꼽히는야나가와강 뱃놀이를 하기 위해 도착  ​2번째에 있는 티켓을 건내면 뱃놀이를 즐길 수 있어요​​  ​​평일인지라 사람이 별로 없을 것 같아 혹시 나 혼자 타는거 아닌가 걱정했는데​다들 어디서 오셨는지 만석으로 출발출발과 동시에 지역에 대한 설명을 해주시는 뱃사공님​  ​천천히 강을 따라 야나가와를 구경​이렇게 강을 따라 배 위에서 보니그냥 걸을때와 다른 느낌과 다들 풍경이 펼쳐지네요​​  ​​중간에 간단한 간식거리를 판매하는 슈퍼가 있어 이곳에서 잠시 멈춰 주전부리를 구입해보았어요 ​생각해보면 후쿠오카여행 필수코스로 유명한야나가와 뱃놀이지만 이번이 처음이였다는이렇게 소소한 재미가 있는걸 왜 지금했지 후회를​그래도 이시국전에 다녀와서 다행이네요 ​​ ​건너편에서 뱃놀이를 즐기시는 분들인데다들 노래도 듣고 박수도 치고 ​왠지 유유자적이라는 말과 넘 잘 어울리네요​​ ​뱃놀이를 마치고 기념으로 사진촬영을 부탁했는데너무나 완벽하게 포즈를 잡아주셨네요 아리가또우~~고자이마스​ ​티켓에는 야나가와 명물음식인 장어덮밥 집도 포함되어원하는 가게에서 세트 메뉴를 하나 선택할 수 있었는데요​원래 가고 싶었던 곳은 휴무로 차선책으로 선택한 곳은 롯큐입니다,​  ​​양념된 밥 위에 소복하게 올라온 장어짭조름하면서 달짝지근한 양념과 고소한 장어그 아래 계란지단과 함께 먹는데 완전 꿀맛​​​ ​장어덮밥을 먹고 마을 산책을 하다가이쁜 카페에 들어가 잠시 쉴려고 했지만바깥 풍경이 너무 이뻐 테이크아웃으로 부탁해마을 풍경을 배경으로 음료를 찰칵!​너무나 SNS감성의 음료 사실 맛은 기억이 가물가물​​ ​​매년 봄철이 되면 벚꽃을 보기 위해 방문했던 일본여행서울과 가깝고 일때문에 자주 방문했던 후쿠오카이제는 후쿠오카여행이라는 단어가 아련하게 느껴지네요​곧 갈 수 있는 날이 오길 기도하면조금씩 올리지 못했던 일본여행이야기를 전해보아요 ​​​ 니시테쓰후쿠오카일본 〒810-0001 福岡県福岡市中央区天神２−22야나가와 뱃놀이 선착장329 Mitsuhashimachi Takahatake, Yanagawa, Fukuoka 832-0826 일본롯큐28 Okinohatamachi, Yanagawa, Fukuoka 832-0065 일본 ​ 인터넷에서 우연히 알게된 하우스텐보스
#
#  ㅎㅎ)  포숑x포키 무조건 먹어야지 저건 왜 한개만 사왔지 후회했을 정도로 맛나게 먹었고 저 명란 시리즈는 당시 명란노처녀를 외치던 ㅋㅋㅋ명란 극호녀들의 구매아이템
#
#   아사히 공장 입구!그래도 입구는 찍어야 할 것 같아서 찍었는데 사진 한 장은 심하게 흔들렸네 ㅠㅠ ㅋㅋㅋㅋㅋ   하카타 공장의 제조량을 350ml 캔으로 환산하면 그래서 얼마라는거야 ㅋㅋㅋㅋㅋㅋㅋ 빠른걸음으로 가면서 찍어야 할 건 찍어야겠다고 생각해서 저래 찍었는데 정작 중요한걸 못찍었구만 ㅠㅠ ㅋㅋㅋ  한국에서 아사히 맥주의 활동! ㅋㅋ  어머어머, 우리 인성님 ㅋㅋㅋㅋ  여기서부터 가이드 설명을 들을 수 있었다 ㅋㅋ 맥주의 원재료를 볼 수 있고 만질 수도 있음 ㅋㅋ  아사히 맥주 제조 과정! 아사히 맥주를 숙성하는 저장고의 높이는 무려 22m터나 된다고!!  아사히 맥주공장 설비도 구경할 수 있었음 ㅋㅋ  1분간 제조량이 얼마나 많은지 한 컷에 담을래야 담을 수가 없음 ㅋㅋ   아사히 맥주공장에서 생산되는 맥주를 전문가가 매일 마셔보고 맛에 이상이 있는지 향기를 체크 하는 등 꼼꼼하게 검수가 이루어 진다고 ㅋㅋ누가 생각이 나더라며 ㅋㅋ  가이드 언니랑 옷이 똑같길래 ㅋㅋ여기 유니폼인가봄 ㅋㅋ  투어 마치고 시음장소로 돌아가는 길 ㅋㅋ이게 다 아사히 그룹의 상품인가 보네? ㅋㅋ  시음하러 진짜 갑니다 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ  시음 장소 도착! ㅋㅋ  각 테이블마다 번호가 있어서 번호에 맞는 자리에 앉으면 됨 ㅋㅋ  총 세 잔의 맥주를 시음할 수 있는 아사히 맥주공장! ㅋㅋ전문가들이 맥주를 따라줍니다 ㅋㅋㅋㅋㅋ  제일 먼저 받은 아사히 슈퍼 드라이!포토존에서 한 컷 ㅋㅋ거품보소 ㅋㅋㅋ  가지고 오는 동안 거품 꺼졌 ㅠㅠ ㅋㅋㅋ 술안주로 인당 한봉지씩 까까도 줌 ㅋㅋ청도 맥주공장 투어 갔을때 줬던 땅콩이 참 맛있었다고 깔깔깔 ㅋㅋ 공장에서 바로 먹는 생맥주가 젤 맛있는거 다 알죠? ㅋㅋㅋㅋ캔맥주, 병맥주 맛 못따라옴 ㅋㅋㅋ   술이 아주 술술술 ㅋㅋ 음료 서비스 끝났다고 신난 직원들? ㅋㅋㅋㅋㅋ  다음 맥주 시음하러 총총 ㅋㅋ  아사히 수퍼 드라이 엑스트라  콜드 블랙 or 아사히 수퍼 드라이 엑스트라 콜드 중 하나만 마실 수 있음! 맥주가 가장 맛있다는 엑스트라콜드 -2도 ㅋㅋㅋ  엑스트라콜드블랙 두 잔 ㅋㅋ  엑스트라콜드 한 잔 ㅋㅋ한모금 하고 나란히 한 컷 ㅋㅋ   마지막은 프리미엄맥주 호죠!  배불러서 이건 한 잔만 받아와서 나눠 마셨던 것 같은데 가물가물 ㅋㅋ 여튼 다 맛있게 마셨다 ㅋㅋ 맥주를 다 마신 후엔 기념품 가게 구경하긔 ㅋㅋㅋ  당시 2020 도쿄올림픽 굿즈들도 있었고 ㅋㅋ  당연히 아사히 맥주도 팔고 ㅋㅋ  이건 쿠키인가??? 위스키 선물세트 이거 너무 귀여웠음 ㅋㅋ  글라스도 팔고 ㅋㅋ  위스키 초콜릿이라도 하나 사올껄 ㅠㅠ기념품 구경 야무지게 하고 엄마만 맥주를 샀다고 한다 ㅋㅋㅋㅋㅋ  네 여기는 후쿠오카 아사히 맥주 공장입니다 ㅋㅋㅋㅋ  관람후 포토존으로 돌아와 ㅋㅋ   세모녀 셀카찍고 ㅋㅋㅋ  이젠 돌아가야할 시간 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ  공장 견학 마치고 나서도 이렇게 비가 주룩주룩 내렸고요 ㅠㅠ맛있는 맥주도 시음하고 공장 견학도 하고 꿀잼이었던 아사히 맥주공장 ㅋㅋ아주 짱이었긔 ㅋㅋㅋㅋ  아사히맥주 하카타공장3 Chome-1-1 Takeshita, Hakata Ward, Fukuoka, 812-0895 일본 프레스버터샌드 사고 이것저것 계획에 없던 쇼핑에 막판엔 택시까지 타는 바람에 환전한 돈을 모두 탕진함 ㅠㅠ ㅋㅋ해외여행 최초로 돈이 부족한 경험을 했다고 한다 ㅠㅠ ㅋㅋㅋㅋㅋㅋㅋ그래서 만원인가 넣고 긴급 환전까지 했었는데 ㅠㅠ ㅋㅋㅋㅋㅋ공항으로 가야하는 버스는 타야하니까? ㅋㅋㅋㅋㅋ 공항가는 버스 티켓 사고 공항가기 직전까지 아주 그냥 비가 ㅠㅠㅠ근데 진짜 얼마 안내린것 처럼 보이는게 함정 ㅠㅠ ㅋㅋㅋ  여행의 묘미는 또 쇼핑 아니겠냐며 ㅋㅋㅋ후쿠오카 카페투어하면서 드립백 사냥 ㅋㅋ드립백 헌터둘 ㅋㅋ첫날 신나서 호텔 침대에 올려놓고 사진 찍음 ㅋㅋ ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ누가보면 장사꾼인줄 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ간단한 먹거리랑 직장동료들, 지인들 좀 챙긴다고  ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ면세점에서는 차만 두개 정도 샀었는데 ㅋㅋㅋ암튼 다이소, 돈키호테, 백화점 등등 돌면서 주섬주섬 담아온 쇼핑 결과물이라며 ㅋㅋ  아, 그리고 이거 진짜 맛있음 ㅠㅠ진저젤리라서 신기해봐서 사봤는데 에이미랑 이거 너무 맛있다고 쟁여올껄 하고 후회했다 ㅠㅠ  유후인 몬치치샵에서 데려온 베비치치들은 귀여우니까 단독샷으로 ㅋㅋㅋㅋ​이상 2박3일의 후쿠오카 여행기 끝 ㅋㅋㅋㅋ​이제 이탈리아 여행기만 남았네 ㅠㅠ ㅋㅋㅋㅋㅋㅋㅋㅋ  화이팅 한 번 해보자 ㅋㅋㅋㅋ​ 백신 접종 때문에 나고야로 만족해야했던 아쉬운 지난번 휴일 이후 줄곧 기다려왔던 연휴
#
# 계란 올리기를 실패했어욬ㅋㅋㅋㅋㅋ​속상했던 기억이 있는데다시봐도 넘 웃기네요,,,,​맛은 기대한 만큼 맛있었는데먹다 보니까 약간 물리더라고요!추가 토핑에 구운 마늘이었나? 바삭한 마늘 같은 게 있었는데친구는 마늘 토핑을 추가했길래 친구 꺼 먹어보니까 함바그랑 조합이 좋더라고요 다음에 또 가게 된다면 추가해서 먹어보고 싶네요!​​​그러고는 다시 쇼핑쇼핑~~파르코 백화점에서 여기저기 돌아다녔어요​  ​제가 좋아는 원피스 스토어!!일본을 가면 무조건 일정에 포함시키는데 가격대는 비싸지만,,,​  ​신은 나니까 좋아요ㅋㅋㅋㅋ​​사진은 없지만제가 WEGO 위고라는 브랜드를좋아하는데 독특하기도 하고구경하는데 재밌거든요!타이다이 양말이랑 목걸이를 구매했는데 양말을 더 사 올걸 하고후회했던 기억이 있네요 사고 싶은 건 사세요!!
#
#  나중에 후회합니다
#
# 다들 카이센동 먹을껄,,이라면서 후회함ㅌㅋㅋㅋㅋ난 아주 잘 먹음:) 저기 미소시루가 진짜…환상 밥 먹고 차로 3분?정도 달리다보니 유명한 바다가 나왔다!! 그네가 있는걸로 유명한데 사람이 좀 많아서 기다려야지 탈 수 있었음! 날이 좀 더 화창했으면 좋았을텐데ㅠㅠ 이런 그네가 주르륵 있는데 다들 여기서 인스타 사진 많이 찍던데…결국 못건짐^

# %%
for n in range(10):
    text = str(df.iloc[:,:5]['score_two_word'][n])+str(df.iloc[:,:4]['score_one_word'][n])  #
    tokens_ko=okt.nouns(text)
    tokens_ko
    ko=nltk.Text(tokens_ko, name=city)

    plt.figure(figsize=(12,8))
    plt.title(city_list[n])
    ko.plot(20)
    plt.show()

    #워드클라우드
    data = ko.vocab().most_common(50) #단어갯수 조절
    airplain_mask=np.array(Image.open("C:/Users/twentystones/Desktop/사회연결망분석텀프로젝트/airplain.jfif"))
    wc=WordCloud(font_path='c:\windows\Fonts\malgun.ttf',background_color='white', relative_scaling=0.2,
                 stopwords=stop_words).generate_from_frequencies(dict(data))
    plt.figure(figsize=(12,8))
    plt.imshow(wc)
    plt.axis('off')
    plt.title(city_list[n])
    #plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'score_two_word'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-b858ac43bf01> in <module>
#       1 for n in range(10):
# ----> 2     text = str(df.iloc[:,:5]['score_two_word'][n])+str(df.iloc[:,:4]['score_one_word'][n])  #
#       3     tokens_ko=okt.nouns(text)
#       4     tokens_ko
#       5     ko=nltk.Text(tokens_ko, name=city)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'score_two_word'

# %%
for n in range(10):
    text = str(df.iloc[:,:5]['score_mtwo_word'][n])+str(df.iloc[:,:4]['score_mone_word'][n])  #
    tokens_ko=okt.nouns(text)
    tokens_ko
    ko=nltk.Text(tokens_ko, name=city)

    plt.figure(figsize=(12,8))
    plt.title(city_list[n])
    ko.plot(20)
    #plt.show()

    #워드클라우드
    data = ko.vocab().most_common(50) #단어갯수 조절
    airplain_mask=np.array(Image.open("C:/Users/twentystones/Desktop/사회연결망분석텀프로젝트/airplain.jfif"))
    wc=WordCloud(font_path='c:\windows\Fonts\malgun.ttf',background_color='black', relative_scaling=0.2,
                 stopwords=stop_words).generate_from_frequencies(dict(data))
    plt.figure(figsize=(12,8))
    plt.imshow(wc)
    plt.axis('off')
    plt.title(city_list[n])
    #plt.show()

# %%
'''
#고치기 귀찮아서 넘김 필요하면 나중에 쓰기
#연어 : 단어들이 연결되서 사용되는거
from konlpy.tag import Kkma
from konlpy.corpus import kolaw
from konlpy.utils import pprint
from nltk import collocations #이웃사용된 연어사용

measures = collocations.BigramAssocMeasures()
tagged_words = Kkma().pos(text) #형태소분석한 결과가 형태소-품사 딕셔너리로 나옴

stopwords=[u'에게'] #u는 포맷정의래
words = [w for w, t in tagged_words]   #품사빼고 형태소만 words에 저장
finder = collocations.BigramCollocationFinder.from_words(words)
finder.apply_word_filter(lambda w:len(w)<2 or w in stopwords)  #두 단어 주요 키워드
finder.apply_freq_filter(4)   #최소 4번은 나온것
pprint(finder.nbest(measures.pmi,10))  #연어 사용지수높은 상위10개
'''
# Out:
# "\n#고치기 귀찮아서 넘김 필요하면 나중에 쓰기\n#연어 : 단어들이 연결되서 사용되는거\nfrom konlpy.tag import Kkma\nfrom konlpy.corpus import kolaw\nfrom konlpy.utils import pprint\nfrom nltk import collocations #이웃사용된 연어사용\n\nmeasures = collocations.BigramAssocMeasures()\ntagged_words = Kkma().pos(text) #형태소분석한 결과가 형태소-품사 딕셔너리로 나옴\n\nstopwords=[u'에게'] #u는 포맷정의래\nwords = [w for w, t in tagged_words]   #품사빼고 형태소만 words에 저장\nfinder = collocations.BigramCollocationFinder.from_words(words)\nfinder.apply_word_filter(lambda w:len(w)<2 or w in stopwords)  #두 단어 주요 키워드\nfinder.apply_freq_filter(4)   #최소 4번은 나온것\npprint(finder.nbest(measures.pmi,10))  #연어 사용지수높은 상위10개\n"
